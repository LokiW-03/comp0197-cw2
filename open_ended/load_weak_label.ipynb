# %%
import glob
import os


all_files = sorted(glob.glob(os.path.join('../data', 'images', f'*.jpg')))

# extract file names from all_files
all_files = [os.path.basename(f) for f in all_files]

# %%
train_split = all_files[:int(len(all_files) * 0.7)]

# %%
len(train_split)
# Out:
# 5173

# %%
data = 'weak_labels/weak_labels_train_before.pkl'

import pickle
# Open the file in binary read mode ('rb')
with open(data, 'rb') as f:
    # Load the data from the file
    loaded_data = pickle.load(f)

# %%
len(loaded_data)
# Out:
# 5158

# %%
for n in sorted(loaded_data):
    print(n)
# Out:
# Abyssinian_1.jpg
# Abyssinian_10.jpg
# Abyssinian_100.jpg
# Abyssinian_101.jpg
# Abyssinian_102.jpg
# Abyssinian_103.jpg
# Abyssinian_104.jpg
# Abyssinian_105.jpg
# Abyssinian_106.jpg
# Abyssinian_107.jpg
# Abyssinian_108.jpg
# Abyssinian_109.jpg
# Abyssinian_11.jpg
# Abyssinian_110.jpg
# Abyssinian_111.jpg
# Abyssinian_112.jpg
# Abyssinian_113.jpg
# Abyssinian_114.jpg
# Abyssinian_115.jpg
# Abyssinian_116.jpg
# Abyssinian_117.jpg
# Abyssinian_118.jpg
# Abyssinian_119.jpg
# Abyssinian_12.jpg
# Abyssinian_120.jpg
# Abyssinian_121.jpg
# Abyssinian_122.jpg
# Abyssinian_123.jpg
# Abyssinian_124.jpg
# Abyssinian_125.jpg
# Abyssinian_126.jpg
# Abyssinian_127.jpg
# Abyssinian_128.jpg
# Abyssinian_129.jpg
# Abyssinian_13.jpg
# Abyssinian_130.jpg
# Abyssinian_131.jpg
# Abyssinian_132.jpg
# Abyssinian_133.jpg
# Abyssinian_134.jpg
# Abyssinian_135.jpg
# Abyssinian_136.jpg
# Abyssinian_137.jpg
# Abyssinian_138.jpg
# Abyssinian_139.jpg
# Abyssinian_14.jpg
# Abyssinian_140.jpg
# ...

# %%
for f in loaded_data:
    if f not in all_files:
        print(f)

# %%
# those filenames not present in loaded_data, initilize them with default value, point is centrod, crisble is centrold list, bounding box is a centrod sqiare

for f in all_files:
    if f not in loaded_data:
        print(f)
        # loaded_data[f] = {
        #     'points': [(0, 0)],
        #     'scribble': {
        #         'foreground': [(0, 0)],
        #         'background': [(254,254)],
        #     },
        #     'boxes': [(0, 0, 0, 0)],
        # }
# Out:
# Abyssinian_34.jpg
# Egyptian_Mau_129.jpg
# Egyptian_Mau_139.jpg
# Egyptian_Mau_145.jpg
# Egyptian_Mau_162.jpg
# Egyptian_Mau_165.jpg
# Egyptian_Mau_167.jpg
# Egyptian_Mau_177.jpg
# Egyptian_Mau_191.jpg
# Egyptian_Mau_196.jpg
# Egyptian_Mau_20.jpg
# Persian_259.jpg
# japanese_chin_199.jpg
# keeshond_7.jpg
# leonberger_18.jpg
# leonberger_75.jpg
# leonberger_76.jpg
# leonberger_77.jpg
# leonberger_78.jpg
# leonberger_79.jpg
# leonberger_8.jpg
# leonberger_80.jpg
# leonberger_81.jpg
# leonberger_82.jpg
# leonberger_83.jpg
# leonberger_84.jpg
# leonberger_85.jpg
# leonberger_86.jpg
# leonberger_87.jpg
# leonberger_88.jpg
# leonberger_89.jpg
# leonberger_9.jpg
# leonberger_90.jpg
# leonberger_91.jpg
# leonberger_92.jpg
# leonberger_93.jpg
# leonberger_94.jpg
# leonberger_95.jpg
# leonberger_96.jpg
# leonberger_97.jpg
# leonberger_98.jpg
# leonberger_99.jpg
# miniature_pinscher_1.jpg
# miniature_pinscher_10.jpg
# miniature_pinscher_100.jpg
# miniature_pinscher_101.jpg
# ...

# %%
len(loaded_data)
# Out:
# 7390

# %%
loaded_data['american_pit_bull_terrier_146.jpg']
# Out:
# {'points': [(105, 124),
#   (115, 128),
#   (149, 128),
#   (133, 106),
#   (152, 172),
#   (155, 117),
#   (129, 173),
#   (171, 110),
#   (144, 133),
#   (159, 242),
#   (92, 202),
#   (104, 184),
#   (168, 193),
#   (143, 154),
#   (96, 111),
#   (167, 160),
#   (138, 121),
#   (154, 121),
#   (122, 137),
#   (155, 164),
#   (134, 167),
#   (128, 193),
#   (144, 107),
#   (119, 129),
#   (116, 149),
#   (118, 182),
#   (140, 201),
#   (98, 199),
#   (145, 170),
#   (102, 116)],
#  'scribbles': {'foreground': [(167, 108),
#    (165, 110),
#    (163, 111),
#    (161, 112),
#    (159, 113),
#    (157, 114),
#    (155, 115),
#    (153, 115),
#    (151, 116),
#    (149, 116),
#    (147, 117),
#    (145, 118),
#    (143, 120),
#    (141, 122),
#    (139, 124),
#    (137, 126),
#    (135, 128),
#    (133, 130),
#    (131, 132),
#    (129, 134),
#    (129, 136),
#    (129, 138),
#    (129, 140),
#    (129, 142),
#    (129, 144),
#    (129, 146),
#    (129, 148),
#    (129, 150),
# ...

# %%
loaded_data['english_setter_189.jpg']
# Out:
# {'tags': [1],
#  'point': [(147, 89),
#   (152, 372),
#   (179, 220),
#   (191, 361),
#   (223, 275),
#   (235, 404),
#   (241, 301),
#   (251, 284),
#   (279, 387),
#   (290, 337)],
#  'scatter': [(130, 254),
#   (150, 325),
#   (157, 203),
#   (163, 193),
#   (163, 369),
#   (166, 225),
#   (173, 76),
#   (180, 295),
#   (191, 344),
#   (205, 260),
#   (225, 104),
#   (243, 297),
#   (251, 43),
#   (254, 79),
#   (256, 292),
#   (262, 157),
#   (262, 185),
#   (267, 33),
#   (287, 251),
#   (309, 104)],
#  'scribbles': {'foreground': [(356, 299),
#    (355, 298),
#    (354, 297),
#    (353, 297),
#    (352, 296),
#    (351, 296),
#    (350, 296),
#    (349, 296),
#    (348, 296),
#    (347, 296),
#    (346, 296),
#    (345, 296),
#    (344, 297),
#    (343, 297),
#    (342, 297),
#    (341, 297),
#    (340, 297),
#    (339, 298),
#    (338, 298),
#    (337, 298),
#    (336, 298),
#    (335, 298),
#    (334, 299),
#    (333, 299),
#    (332, 299),
#    (331, 299),
#    (330, 299),
# ...
